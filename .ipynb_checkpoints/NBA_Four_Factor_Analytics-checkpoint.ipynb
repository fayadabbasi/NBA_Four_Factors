# %%
import sqlalchemy as sqa
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
engine = create_engine('postgresql+psycopg2://postgres:docker@localhost:5432/nbafourfactor')

# %%
df = pd.read_sql_query('select * FROM nbafourfactorfour', con=engine)

# %%
df.head()
# Out:
#                   Player   MP  FG  FGA  3P  FT  ORB  TOV  FTA  DRB  PTS  \
# 0         Boston Celtics  240  36   88   8  19    9   10   25   37   99
# 1    Cleveland Cavaliers  240  38   83   5  21    9   17   25   41  102
# 2        Houston Rockets  240  47   97  15  13   10   12   19   33  122
# 3  Golden State Warriors  240  43   80  16  19    6   17   21   35  121
# 4      Charlotte Hornets  240  29   73   9  23    3   17   29   44   90
#
#                         Date       eFG   TOV_per   ORB_per       FTr  \
# 0   8:01 PM  October 17 2017  0.454545  0.091743  0.195652  0.215909
# 1   8:01 PM  October 17 2017  0.487952  0.153153  0.180000  0.253012
# 2  10:30 PM  October 17 2017  0.561856  0.102249  0.232558  0.134021
# 3  10:30 PM  October 17 2017  0.637500  0.160015  0.146341  0.237500
# 4   7:00 PM  October 18 2017  0.458904  0.165434  0.063830  0.315068
#
#           id_t  loc
# 0  20171017CLE  CLE
# 1  20171017CLE  CLE
# 2  20171017GSW  GSW
# 3  20171017GSW  GSW
# 4  20171018DET  DET

# %%
df_away = df.iloc[::2]

# %%
df_away[:10]
# Out:
#                   Player   MP  FG  FGA  3P  FT  ORB  TOV  FTA  DRB  PTS  \
# 0         Boston Celtics  240  36   88   8  19    9   10   25   37   99
# 2        Houston Rockets  240  47   97  15  13   10   12   19   33  122
# 4      Charlotte Hornets  240  29   73   9  23    3   17   29   44   90
# 6          Brooklyn Nets  240  45   94  12  29   11   20   32   32  131
# 8             Miami Heat  240  44  101   8  13   11   13   17   33  109
# 10    Philadelphia 76ers  240  43   93  15  14   11   17   19   37  115
# 12       Milwaukee Bucks  240  38   76   7  25    6   15   30   39  108
# 14  New Orleans Pelicans  240  30   79   7  24   16   17   29   35   91
# 16         Atlanta Hawks  240  48   94   9  12   14   13   15   36  117
# 18        Denver Nuggets  240  36   77  13  11    7   20   12   31   96
#
#                          Date       eFG   TOV_per   ORB_per       FTr  \
# 0    8:01 PM  October 17 2017  0.454545  0.091743  0.195652  0.215909
# 2   10:30 PM  October 17 2017  0.561856  0.102249  0.232558  0.134021
# 4    7:00 PM  October 18 2017  0.458904  0.165434  0.063830  0.315068
# 6    7:00 PM  October 18 2017  0.542553  0.156152  0.255814  0.308511
# 8    7:00 PM  October 18 2017  0.475248  0.107014  0.250000  0.128713
# 10   7:00 PM  October 18 2017  0.543011  0.143630  0.229167  0.150538
# 12   7:30 PM  October 18 2017  0.546053  0.143954  0.133333  0.328947
# 14   8:00 PM  October 18 2017  0.424051  0.156307  0.313725  0.303797
# 16   8:30 PM  October 18 2017  0.558511  0.114437  0.280000  0.127660
# 18   9:00 PM  October 18 2017  0.551948  0.195542  0.184211  0.142857
#
#            id_t  loc
# 0   20171017CLE  CLE
# 2   20171017GSW  GSW
# 4   20171018DET  DET
# 6   20171018IND  IND
# 8   20171018ORL  ORL
# 10  20171018WAS  WAS
# 12  20171018BOS  BOS
# 14  20171018MEM  MEM
# 16  20171018DAL  DAL
# 18  20171018UTA  UTA

# %%
df_home = df.iloc[1::2]

# %%
df_home[:10]
# Out:
#                    Player   MP  FG  FGA  3P  FT  ORB  TOV  FTA  DRB  PTS  \
# 1     Cleveland Cavaliers  240  38   83   5  21    9   17   25   41  102
# 3   Golden State Warriors  240  43   80  16  19    6   17   21   35  121
# 5         Detroit Pistons  240  41   96   9  11    9    8   12   38  102
# 7          Indiana Pacers  240  53  102   9  25   14   14   32   33  140
# 9           Orlando Magic  240  43   90   8  22   11   14   29   39  116
# 11     Washington Wizards  240  42   97   6  30   16    9   38   36  120
# 13         Boston Celtics  240  39   91  11  11   11   12   21   32  100
# 15      Memphis Grizzlies  240  39   92   9  16   15   11   28   30  103
# 17       Dallas Mavericks  240  38   86  17  18    9   15   21   32  111
# 19              Utah Jazz  240  41   81   9  15    6   15   16   30  106
#
#                          Date       eFG   TOV_per   ORB_per       FTr  \
# 1    8:01 PM  October 17 2017  0.487952  0.153153  0.180000  0.253012
# 3   10:30 PM  October 17 2017  0.637500  0.160015  0.146341  0.237500
# 5    7:00 PM  October 18 2017  0.473958  0.073206  0.191489  0.114583
# 7    7:00 PM  October 18 2017  0.563725  0.107626  0.297872  0.245098
# 9    7:00 PM  October 18 2017  0.522222  0.119904  0.220000  0.244444
# 11   7:00 PM  October 18 2017  0.463918  0.073338  0.307692  0.309278
# 13   7:30 PM  October 18 2017  0.489011  0.106914  0.255814  0.120879
# 15   8:00 PM  October 18 2017  0.472826  0.095387  0.333333  0.173913
# 17   8:30 PM  October 18 2017  0.540698  0.136067  0.219512  0.209302
# 19   9:00 PM  October 18 2017  0.561728  0.145575  0.166667  0.185185
#
#            id_t  loc
# 1   20171017CLE  CLE
# 3   20171017GSW  GSW
# 5   20171018DET  DET
# 7   20171018IND  IND
# 9   20171018ORL  ORL
# 11  20171018WAS  WAS
# 13  20171018BOS  BOS
# 15  20171018MEM  MEM
# 17  20171018DAL  DAL
# 19  20171018UTA  UTA

# %%
print("The mean for home games is {} and the standard deviation is {}".format(np.mean(df_home['eFG']), np.std(df_home['eFG'])))
# Out:
# The mean for home games is 0.5276564054804884 and the standard deviation is 0.06459622826834897

# %%
print("The mean for away games is {} and the standard deviation is {}".format(np.mean(df_away['eFG']), np.std(df_away['eFG'])))
# Out:
# The mean for away games is 0.5163791096119539 and the standard deviation is 0.06458554877697503

# %%
print("The mean for home games is {} and the standard deviation is {}".format(np.mean(df_home['TOV_per']), np.std(df_home['TOV_per'])))
# Out:
# The mean for home games is 0.12423100555337355 and the standard deviation is 0.03244379325617496

# %%
print("The mean for away games is {} and the standard deviation is {}".format(np.mean(df_away['TOV_per']), np.std(df_away['TOV_per'])))
# Out:
# The mean for away games is 0.12554110383684883 and the standard deviation is 0.03385390454276672

# %%
print("The mean for home games is {} and the standard deviation is {}".format(np.mean(df_home['ORB_per']), np.std(df_home['ORB_per'])))
# Out:
# The mean for home games is 0.22211444418591597 and the standard deviation is 0.07028913789045602

# %%
print("The mean for away games is {} and the standard deviation is {}".format(np.mean(df_away['ORB_per']), np.std(df_away['ORB_per'])))
# Out:
# The mean for away games is 0.22318400302373942 and the standard deviation is 0.07142021038969572

# %%
print("The mean for home games is {} and the standard deviation is {}".format(np.mean(df_home['FTr']), np.std(df_home['FTr'])))
# Out:
# The mean for home games is 0.20091515532175722 and the standard deviation is 0.0756645017443526

# %%
print("The mean for away games is {} and the standard deviation is {}".format(np.mean(df_away['FTr']), np.std(df_away['FTr'])))
# Out:
# The mean for away games is 0.19516871152779816 and the standard deviation is 0.07420748079815775

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(15,5), sharex=True, sharey=True)

ax1.hist(df_home['eFG'], bins=30)
ax1.set_title('Home eFG')
ax1.grid(which='major', linestyle='-', linewidth='0.3')
ax2.hist(df_away['eFG'], bins=30, color='orange')
ax2.grid(linewidth='0.3')
ax2.set_title('Away eFG')
# Out:
# Text(0.5,1,'Away eFG')

# %%
fig, ax = plt.subplots(1,1)
ax.hist(df_home['eFG'], bins=100, alpha=0.5)
ax.hist(df_away['eFG'], bins=100, color='orange', alpha=0.4)
ax.grid(which='major', linestyle='-', linewidth='0.3')
ax.axvline(np.mean(df_home['eFG']))
ax.axvline(np.mean(df_away['eFG']), color='orange')
ax.set_title('Home eFG in blue vs Away eFG in orange with mean vertical lines')
# Out:
# Text(0.5,1,'Home eFG in blue vs Away eFG in orange with mean vertical lines')

# %%
efg_stat, efg_pval = stats.ttest_ind(df_home['eFG'], df_away['eFG'])

# %%
print("The mean effective FG% for home games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_home['eFG']), np.std(df_home['eFG'])))
print("The mean effective FG% for away games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_away['eFG']), np.std(df_away['eFG'])))
print("Performing a t-test on the two samples, the t-statistic is {:2.3} and the p-value is {:2.4}".format(efg_stat, efg_pval))
# Out:
# The mean effective FG% for home games is 0.528 and the standard deviation is 0.0646
# The mean effective FG% for away games is 0.516 and the standard deviation is 0.06459
# Performing a t-test on the two samples, the t-statistic is 5.0 and the p-value is 6.044e-07

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(15,5), sharex=True, sharey=True)

ax1.hist(df_home['FTr'], bins=30)
ax1.set_title('Home FTr')
ax1.grid(linewidth='0.3')
ax2.hist(df_away['FTr'], bins=30, color='orange')
ax2.grid(linewidth='0.3')
ax2.set_title('Away FTr')
# Out:
# Text(0.5,1,'Away FTr')

# %%
ftr_stat, ftr_pval = stats.ttest_ind(df_home['FTr'], df_away['FTr'])

# %%
print("The mean Free Throw Rate for home games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_home['FTr']), np.std(df_home['FTr'])))
print("The mean Free Throw Rate for away games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_away['FTr']), np.std(df_away['FTr'])))
print("Performing a t-test on the two samples, the t-statistic is {:2.3} and the p-value is {:2.4}".format(ftr_stat, ftr_pval))
# Out:
# The mean Free Throw Rate for home games is 0.201 and the standard deviation is 0.07566
# The mean Free Throw Rate for away games is 0.195 and the standard deviation is 0.07421
# Performing a t-test on the two samples, the t-statistic is 2.2 and the p-value is 0.02818

# %%
fig, ax = plt.subplots(1,1)
ax.hist(df_home['FTr'], bins=100, alpha=0.5)
ax.hist(df_away['FTr'], bins=100, color='orange', alpha=0.6)
ax.grid(which='major', linestyle='-', linewidth='0.3')
ax.axvline(np.mean(df_home['FTr']))
ax.axvline(np.mean(df_away['FTr']), color='orange')
ax.set_title('Home FTr in blue vs Away FTr in orange with mean vertical lines')
# Out:
# Text(0.5,1,'Home FTr in blue vs Away FTr in orange with mean vertical lines')

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(15,5), sharex=True, sharey=True)

ax1.hist(df_home['ORB_per'], bins=30)
ax1.set_title('Home Offen Reb %')
ax1.grid(linewidth='0.3')
ax2.hist(df_away['ORB_per'], bins=30, color='orange')
ax2.grid(linewidth='0.3')
ax2.set_title('Away Offen Reb %')
# Out:
# Text(0.5,1,'Away Offen Reb %')

# %%
orb_stat, orb_pval = stats.ttest_ind(df_home['ORB_per'], df_away['ORB_per'])

# %%
print("The mean Offensive Rebound Percent for home games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_home['ORB_per']), np.std(df_home['ORB_per'])))
print("The mean Offensive Rebound Percent for away games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_away['ORB_per']), np.std(df_away['ORB_per'])))
print("Performing a t-test on the two samples, the t-statistic is {:2.3} and the p-value is {:2.4}".format(orb_stat, orb_pval))
# Out:
# The mean Offensive Rebound Percent for home games is 0.222 and the standard deviation is 0.07029
# The mean Offensive Rebound Percent for away games is 0.223 and the standard deviation is 0.07142
# Performing a t-test on the two samples, the t-statistic is -0.432 and the p-value is 0.6656

# %% [markdown]
# Even when you run equal_var=False, the p-value is the same so no impact from different variances

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(15,5), sharex=True, sharey=True)

ax1.hist(df_home['TOV_per'], bins=30)
ax1.set_title('Home Turnover %')
ax1.grid(linewidth='0.3')
ax2.hist(df_away['TOV_per'], bins=30, color='orange')
ax2.grid(linewidth='0.3')
ax2.set_title('Away Turnover %')
# Out:
# Text(0.5,1,'Away Turnover %')

# %%
trn_stat, trn_pval = stats.ttest_ind(df_home['TOV_per'], df_away['TOV_per'])

# %%
print("The mean Turnover Percent for home games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_home['TOV_per']), np.std(df_home['TOV_per'])))
print("The mean Turnover Percent for away games is {:2.3} and the standard deviation is {:2.4}".format(np.mean(df_away['TOV_per']), np.std(df_away['TOV_per'])))
print("Performing a t-test on the two samples, the t-statistic is {:2.3} and the p-value is {:2.4}".format(trn_stat, trn_pval))
# Out:
# The mean Turnover Percent for home games is 0.124 and the standard deviation is 0.03244
# The mean Turnover Percent for away games is 0.126 and the standard deviation is 0.03385
# Performing a t-test on the two samples, the t-statistic is -1.13 and the p-value is 0.2579

# %%
analysis_list = ['eFG', 'TOV_per', 'ORB_per', 'FTr']
for items in analysis_list:
    df.hist(column=items, bins=100, linewidth='0.3')

# %%
df_h = pd.read_sql_query('select "Player", loc FROM nbafourfactorfour', con=engine)

# %%
df_h = df_h.reindex(columns=['Player','loc','homeaway'])

# %%
df_h.head()
# Out:
#                   Player  loc  homeaway
# 0         Boston Celtics  CLE       NaN
# 1    Cleveland Cavaliers  CLE       NaN
# 2        Houston Rockets  GSW       NaN
# 3  Golden State Warriors  GSW       NaN
# 4      Charlotte Hornets  DET       NaN

# %%
dict_conv = {
    'ATL': 'Atlanta Hawks',
    'BOS': 'Boston Celtics',
    'BRK': 'Brooklyn Nets',
    'CHI': 'Chicago Bulls',
    'CHO': 'Charlotte Hornets',
    'CLE': 'Cleveland Cavaliers',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'NOP': 'New Orleans Pelicans',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHO': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'SAC': 'Sacramento Kings',
    'SAS': 'San Antonio Spurs',
    'TOR': 'Toronto Raptors',
    'UTA': 'Utah Jazz',
    'WAS': 'Washington Wizards'}

# %%
len([k for k,v in dict_conv.items()])
# Out:
# 30

# %%
dict_conv['ATL']
# Out:
# 'Atlanta Hawks'

# %%
len(df_h['loc'])
# Out:
# 3282

# %%
d = list(zip(df_h['loc'],df_h['Player']))

# %%
d
# Out:
# [('CLE', 'Boston Celtics'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('GSW', 'Houston Rockets'),
#  ('GSW', 'Golden State Warriors'),
#  ('DET', 'Charlotte Hornets'),
#  ('DET', 'Detroit Pistons'),
#  ('IND', 'Brooklyn Nets'),
#  ('IND', 'Indiana Pacers'),
#  ('ORL', 'Miami Heat'),
#  ('ORL', 'Orlando Magic'),
#  ('WAS', 'Philadelphia 76ers'),
#  ('WAS', 'Washington Wizards'),
#  ('BOS', 'Milwaukee Bucks'),
#  ('BOS', 'Boston Celtics'),
#  ('MEM', 'New Orleans Pelicans'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('DAL', 'Atlanta Hawks'),
#  ('DAL', 'Dallas Mavericks'),
#  ('UTA', 'Denver Nuggets'),
#  ('UTA', 'Utah Jazz'),
#  ('SAS', 'Minnesota Timberwolves'),
#  ('SAS', 'San Antonio Spurs'),
#  ('PHO', 'Portland Trail Blazers'),
#  ('PHO', 'Phoenix Suns'),
#  ('SAC', 'Houston Rockets'),
#  ('SAC', 'Sacramento Kings'),
#  ('TOR', 'Chicago Bulls'),
#  ('TOR', 'Toronto Raptors'),
#  ('OKC', 'New York Knicks'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('LAL', 'Los Angeles Clippers'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('CHO', 'Atlanta Hawks'),
#  ('CHO', 'Charlotte Hornets'),
#  ('IND', 'Portland Trail Blazers'),
#  ('IND', 'Indiana Pacers'),
#  ('MIL', 'Cleveland Cavaliers'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('PHI', 'Boston Celtics'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('WAS', 'Detroit Pistons'),
#  ('WAS', 'Washington Wizards'),
#  ('BRK', 'Orlando Magic'),
#  ('BRK', 'Brooklyn Nets'),
#  ('MIN', 'Utah Jazz'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('DAL', 'Sacramento Kings'),
#  ('DAL', 'Dallas Mavericks'),
#  ('NOP', 'Golden State Warriors'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('PHO', 'Los Angeles Lakers'),
#  ('PHO', 'Phoenix Suns'),
#  ('TOR', 'Philadelphia 76ers'),
#  ('TOR', 'Toronto Raptors'),
#  ('CHI', 'San Antonio Spurs'),
#  ('CHI', 'Chicago Bulls'),
#  ('CLE', 'Orlando Magic'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('HOU', 'Dallas Mavericks'),
#  ('HOU', 'Houston Rockets'),
#  ('MEM', 'Golden State Warriors'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIA', 'Indiana Pacers'),
#  ('MIA', 'Miami Heat'),
#  ('NYK', 'Detroit Pistons'),
#  ('NYK', 'New York Knicks'),
#  ('MIL', 'Portland Trail Blazers'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('DEN', 'Sacramento Kings'),
#  ('DEN', 'Denver Nuggets'),
#  ('UTA', 'Oklahoma City Thunder'),
#  ('UTA', 'Utah Jazz'),
#  ('LAC', 'Phoenix Suns'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('BRK', 'Atlanta Hawks'),
#  ('BRK', 'Brooklyn Nets'),
#  ('OKC', 'Minnesota Timberwolves'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('LAL', 'New Orleans Pelicans'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('DET', 'Philadelphia 76ers'),
#  ('DET', 'Detroit Pistons'),
#  ('MIA', 'Atlanta Hawks'),
#  ('MIA', 'Miami Heat'),
#  ('HOU', 'Memphis Grizzlies'),
#  ('HOU', 'Houston Rockets'),
#  ('MIL', 'Charlotte Hornets'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('DAL', 'Golden State Warriors'),
#  ('DAL', 'Dallas Mavericks'),
#  ('SAS', 'Toronto Raptors'),
#  ('SAS', 'San Antonio Spurs'),
#  ('DEN', 'Washington Wizards'),
#  ('DEN', 'Denver Nuggets'),
#  ('PHO', 'Sacramento Kings'),
#  ('PHO', 'Phoenix Suns'),
#  ('CLE', 'Chicago Bulls'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('ORL', 'Brooklyn Nets'),
#  ('ORL', 'Orlando Magic'),
#  ('BOS', 'New York Knicks'),
#  ('BOS', 'Boston Celtics'),
#  ('MIN', 'Indiana Pacers'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('POR', 'New Orleans Pelicans'),
#  ('POR', 'Portland Trail Blazers'),
#  ('LAC', 'Utah Jazz'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('CHO', 'Denver Nuggets'),
#  ('CHO', 'Charlotte Hornets'),
#  ('DET', 'Minnesota Timberwolves'),
#  ('DET', 'Detroit Pistons'),
#  ('PHI', 'Houston Rockets'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('BRK', 'Cleveland Cavaliers'),
#  ('BRK', 'Brooklyn Nets'),
#  ('MIA', 'San Antonio Spurs'),
#  ('MIA', 'Miami Heat'),
#  ('OKC', 'Indiana Pacers'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('DAL', 'Memphis Grizzlies'),
#  ('DAL', 'Dallas Mavericks'),
#  ('PHO', 'Utah Jazz'),
#  ('PHO', 'Phoenix Suns'),
#  ('GSW', 'Toronto Raptors'),
#  ('GSW', 'Golden State Warriors'),
#  ('LAL', 'Washington Wizards'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('CHI', 'Atlanta Hawks'),
#  ('CHI', 'Chicago Bulls'),
#  ('MEM', 'Dallas Mavericks'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIL', 'Boston Celtics'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('POR', 'Los Angeles Clippers'),
#  ('POR', 'Portland Trail Blazers'),
#  ('SAC', 'New Orleans Pelicans'),
#  ('SAC', 'Sacramento Kings'),
#  ('CHO', 'Houston Rockets'),
#  ('CHO', 'Charlotte Hornets'),
#  ('ORL', 'San Antonio Spurs'),
#  ('ORL', 'Orlando Magic'),
#  ('ATL', 'Denver Nuggets'),
#  ('ATL', 'Atlanta Hawks'),
#  ('NYK', 'Brooklyn Nets'),
#  ('NYK', 'New York Knicks'),
#  ('MIN', 'Oklahoma City Thunder'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('GSW', 'Washington Wizards'),
#  ('GSW', 'Golden State Warriors'),
#  ('LAL', 'Toronto Raptors'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('NOP', 'Cleveland Cavaliers'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('CHI', 'Oklahoma City Thunder'),
#  ('CHI', 'Chicago Bulls'),
#  ('MEM', 'Houston Rockets'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIA', 'Boston Celtics'),
#  ('MIA', 'Miami Heat'),
#  ('DAL', 'Philadelphia 76ers'),
#  ('DAL', 'Dallas Mavericks'),
#  ('UTA', 'Los Angeles Lakers'),
#  ('UTA', 'Utah Jazz'),
#  ('POR', 'Phoenix Suns'),
#  ('POR', 'Portland Trail Blazers'),
#  ('LAC', 'Detroit Pistons'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('ATL', 'Milwaukee Bucks'),
#  ('ATL', 'Atlanta Hawks'),
#  ('IND', 'San Antonio Spurs'),
#  ('IND', 'Indiana Pacers'),
#  ('BRK', 'Denver Nuggets'),
#  ('BRK', 'Brooklyn Nets'),
#  ('CHO', 'Orlando Magic'),
#  ('CHO', 'Charlotte Hornets'),
#  ('SAC', 'Washington Wizards'),
#  ('SAC', 'Sacramento Kings'),
#  ('CLE', 'New York Knicks'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('GSW', 'Detroit Pistons'),
#  ('GSW', 'Golden State Warriors'),
#  ('BOS', 'San Antonio Spurs'),
#  ('BOS', 'Boston Celtics'),
#  ('MIA', 'Minnesota Timberwolves'),
#  ('MIA', 'Miami Heat'),
#  ('NYK', 'Denver Nuggets'),
#  ('NYK', 'New York Knicks'),
#  ('HOU', 'Philadelphia 76ers'),
#  ('HOU', 'Houston Rockets'),
#  ('MEM', 'Charlotte Hornets'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('NOP', 'Orlando Magic'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('UTA', 'Dallas Mavericks'),
#  ('UTA', 'Utah Jazz'),
#  ('POR', 'Toronto Raptors'),
#  ('POR', 'Portland Trail Blazers'),
#  ('LAC', 'Golden State Warriors'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('IND', 'Sacramento Kings'),
#  ('IND', 'Indiana Pacers'),
#  ('BRK', 'Phoenix Suns'),
#  ('BRK', 'Brooklyn Nets'),
#  ('MIL', 'Oklahoma City Thunder'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('LAL', 'Detroit Pistons'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('CHO', 'Milwaukee Bucks'),
#  ('CHO', 'Charlotte Hornets'),
#  ('CLE', 'Indiana Pacers'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('PHI', 'Atlanta Hawks'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('WAS', 'Phoenix Suns'),
#  ('WAS', 'Washington Wizards'),
#  ('BOS', 'Sacramento Kings'),
#  ('BOS', 'Boston Celtics'),
#  ('MIA', 'Chicago Bulls'),
#  ('MIA', 'Miami Heat'),
#  ('MEM', 'Orlando Magic'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('NOP', 'Minnesota Timberwolves'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('NYK', 'Houston Rockets'),
#  ('NYK', 'New York Knicks'),
#  ('DEN', 'Toronto Raptors'),
#  ('DEN', 'Denver Nuggets'),
#  ('UTA', 'Portland Trail Blazers'),
#  ('UTA', 'Utah Jazz'),
#  ('LAC', 'Dallas Mavericks'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('SAS', 'Golden State Warriors'),
#  ('SAS', 'San Antonio Spurs'),
#  ('POR', 'Los Angeles Lakers'),
#  ('POR', 'Portland Trail Blazers'),
#  ('DET', 'Milwaukee Bucks'),
#  ('DET', 'Detroit Pistons'),
#  ('ORL', 'Chicago Bulls'),
#  ('ORL', 'Orlando Magic'),
#  ('PHI', 'Indiana Pacers'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('WAS', 'Cleveland Cavaliers'),
#  ('WAS', 'Washington Wizards'),
#  ('ATL', 'Houston Rockets'),
#  ('ATL', 'Atlanta Hawks'),
#  ('NYK', 'Phoenix Suns'),
#  ('NYK', 'New York Knicks'),
#  ('DAL', 'New Orleans Pelicans'),
#  ('DAL', 'Dallas Mavericks'),
#  ('SAS', 'Charlotte Hornets'),
#  ('SAS', 'San Antonio Spurs'),
#  ('DEN', 'Miami Heat'),
#  ('DEN', 'Denver Nuggets'),
#  ('UTA', 'Toronto Raptors'),
#  ('UTA', 'Utah Jazz'),
#  ('OKC', 'Boston Celtics'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('LAL', 'Brooklyn Nets'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('LAC', 'Memphis Grizzlies'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('DET', 'Sacramento Kings'),
#  ('DET', 'Detroit Pistons'),
#  ('CHI', 'New Orleans Pelicans'),
#  ('CHI', 'Chicago Bulls'),
#  ('MIN', 'Dallas Mavericks'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('DEN', 'Golden State Warriors'),
#  ('DEN', 'Denver Nuggets'),
#  ('CLE', 'Atlanta Hawks'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('LAC', 'Miami Heat'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('ORL', 'Boston Celtics'),
#  ('ORL', 'Orlando Magic'),
#  ('TOR', 'Washington Wizards'),
#  ('TOR', 'Toronto Raptors'),
#  ('HOU', 'Utah Jazz'),
#  ('HOU', 'Houston Rockets'),
#  ('SAS', 'Phoenix Suns'),
#  ('SAS', 'San Antonio Spurs'),
#  ('NYK', 'Indiana Pacers'),
#  ('NYK', 'New York Knicks'),
#  ('MIN', 'Charlotte Hornets'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('POR', 'Oklahoma City Thunder'),
#  ('POR', 'Portland Trail Blazers'),
#  ('LAL', 'Memphis Grizzlies'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('ATL', 'Boston Celtics'),
#  ('ATL', 'Atlanta Hawks'),
#  ('PHO', 'Brooklyn Nets'),
#  ('PHO', 'Phoenix Suns'),
#  ('GSW', 'Miami Heat'),
#  ('GSW', 'Golden State Warriors'),
#  ('CLE', 'Milwaukee Bucks'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('IND', 'New Orleans Pelicans'),
#  ('IND', 'Indiana Pacers'),
#  ('WAS', 'Dallas Mavericks'),
#  ('WAS', 'Washington Wizards'),
#  ('NYK', 'Charlotte Hornets'),
#  ('NYK', 'New York Knicks'),
#  ('TOR', 'Chicago Bulls'),
#  ('TOR', 'Toronto Raptors'),
#  ('SAS', 'Los Angeles Clippers'),
#  ('SAS', 'San Antonio Spurs'),
#  ('DEN', 'Brooklyn Nets'),
#  ('DEN', 'Denver Nuggets'),
#  ('UTA', 'Philadelphia 76ers'),
#  ('UTA', 'Utah Jazz'),
#  ('POR', 'Memphis Grizzlies'),
#  ('POR', 'Portland Trail Blazers'),
#  ('SAC', 'Oklahoma City Thunder'),
#  ('SAC', 'Sacramento Kings'),
#  ('DET', 'Indiana Pacers'),
#  ('DET', 'Detroit Pistons'),
#  ('ORL', 'New York Knicks'),
#  ('ORL', 'Orlando Magic'),
#  ('BOS', 'Los Angeles Lakers'),
#  ('BOS', 'Boston Celtics'),
#  ('PHO', 'Miami Heat'),
#  ('PHO', 'Phoenix Suns'),
#  ('GSW', 'Minnesota Timberwolves'),
#  ('GSW', 'Golden State Warriors'),
#  ('WAS', 'Los Angeles Lakers'),
#  ('WAS', 'Washington Wizards'),
#  ('TOR', 'New Orleans Pelicans'),
#  ('TOR', 'Toronto Raptors'),
#  ('HOU', 'Cleveland Cavaliers'),
#  ('HOU', 'Houston Rockets'),
#  ('SAC', 'Philadelphia 76ers'),
#  ('SAC', 'Sacramento Kings'),
#  ('DEN', 'Oklahoma City Thunder'),
#  ('DEN', 'Denver Nuggets'),
#  ('DET', 'Atlanta Hawks'),
#  ('DET', 'Detroit Pistons'),
#  ('BOS', 'Charlotte Hornets'),
#  ('BOS', 'Boston Celtics'),
#  ('CHI', 'Indiana Pacers'),
#  ('CHI', 'Chicago Bulls'),
#  ('OKC', 'Los Angeles Clippers'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('PHO', 'Orlando Magic'),
#  ('PHO', 'Phoenix Suns'),
#  ('SAS', 'Milwaukee Bucks'),
#  ('SAS', 'San Antonio Spurs'),
#  ('UTA', 'Miami Heat'),
#  ('UTA', 'Utah Jazz'),
#  ('POR', 'Brooklyn Nets'),
#  ('POR', 'Portland Trail Blazers'),
#  ('NOP', 'Los Angeles Clippers'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('WAS', 'Atlanta Hawks'),
#  ('WAS', 'Washington Wizards'),
#  ('HOU', 'Memphis Grizzlies'),
#  ('HOU', 'Houston Rockets'),
#  ('NYK', 'Sacramento Kings'),
#  ('NYK', 'New York Knicks'),
#  ('DAL', 'Cleveland Cavaliers'),
#  ('DAL', 'Dallas Mavericks'),
#  ('GSW', 'Philadelphia 76ers'),
#  ('GSW', 'Golden State Warriors'),
#  ('MIL', 'Los Angeles Lakers'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('SAS', 'Chicago Bulls'),
#  ('SAS', 'San Antonio Spurs'),
#  ('DEN', 'Orlando Magic'),
#  ('DEN', 'Denver Nuggets'),
#  ('PHO', 'Minnesota Timberwolves'),
#  ('PHO', 'Phoenix Suns'),
#  ('UTA', 'Brooklyn Nets'),
#  ('UTA', 'Utah Jazz'),
#  ('BOS', 'Toronto Raptors'),
#  ('BOS', 'Boston Celtics'),
#  ('DET', 'Miami Heat'),
#  ('DET', 'Detroit Pistons'),
#  ('IND', 'Houston Rockets'),
#  ('IND', 'Indiana Pacers'),
#  ('OKC', 'Dallas Mavericks'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('WAS', 'Sacramento Kings'),
#  ('WAS', 'Washington Wizards'),
#  ('NYK', 'Cleveland Cavaliers'),
#  ('NYK', 'New York Knicks'),
#  ('MIL', 'Memphis Grizzlies'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('NOP', 'Atlanta Hawks'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('PHO', 'Los Angeles Lakers'),
#  ('PHO', 'Phoenix Suns'),
#  ('UTA', 'Minnesota Timberwolves'),
#  ('UTA', 'Utah Jazz'),
#  ('POR', 'Denver Nuggets'),
#  ('POR', 'Portland Trail Blazers'),
#  ('GSW', 'Orlando Magic'),
#  ('GSW', 'Golden State Warriors'),
#  ('LAC', 'Philadelphia 76ers'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('BRK', 'Boston Celtics'),
#  ('BRK', 'Brooklyn Nets'),
#  ('HOU', 'Toronto Raptors'),
#  ('HOU', 'Houston Rockets'),
#  ('DAL', 'San Antonio Spurs'),
#  ('DAL', 'Dallas Mavericks'),
#  ('ATL', 'Sacramento Kings'),
#  ('ATL', 'Atlanta Hawks'),
#  ('MIA', 'Washington Wizards'),
#  ('MIA', 'Miami Heat'),
#  ('NYK', 'Utah Jazz'),
#  ('NYK', 'New York Knicks'),
#  ('CHO', 'Cleveland Cavaliers'),
#  ('CHO', 'Charlotte Hornets'),
#  ('MEM', 'Indiana Pacers'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIL', 'Detroit Pistons'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('MIN', 'San Antonio Spurs'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('NOP', 'Toronto Raptors'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('OKC', 'Chicago Bulls'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('POR', 'Orlando Magic'),
#  ('POR', 'Portland Trail Blazers'),
#  ('LAL', 'Philadelphia 76ers'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('BOS', 'Golden State Warriors'),
#  ('BOS', 'Boston Celtics'),
#  ('PHO', 'Houston Rockets'),
#  ('PHO', 'Phoenix Suns'),
#  ('IND', 'Detroit Pistons'),
#  ('IND', 'Indiana Pacers'),
#  ('WAS', 'Miami Heat'),
#  ('WAS', 'Washington Wizards'),
#  ('BRK', 'Utah Jazz'),
#  ('BRK', 'Brooklyn Nets'),
#  ('CLE', 'Los Angeles Clippers'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('TOR', 'New York Knicks'),
#  ('TOR', 'Toronto Raptors'),
#  ('CHI', 'Charlotte Hornets'),
#  ('CHI', 'Chicago Bulls'),
#  ('SAS', 'Oklahoma City Thunder'),
#  ('SAS', 'San Antonio Spurs'),
#  ('DAL', 'Minnesota Timberwolves'),
#  ('DAL', 'Dallas Mavericks'),
#  ('SAC', 'Portland Trail Blazers'),
#  ('SAC', 'Sacramento Kings'),
#  ('DEN', 'New Orleans Pelicans'),
#  ('DEN', 'Denver Nuggets'),
#  ('LAL', 'Phoenix Suns'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('CHO', 'Los Angeles Clippers'),
#  ('CHO', 'Charlotte Hornets'),
#  ('ORL', 'Utah Jazz'),
#  ('ORL', 'Orlando Magic'),
#  ('ATL', 'Boston Celtics'),
#  ('ATL', 'Atlanta Hawks'),
#  ('PHI', 'Golden State Warriors'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('MEM', 'Houston Rockets'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('DAL', 'Milwaukee Bucks'),
#  ('DAL', 'Dallas Mavericks'),
#  ('POR', 'Sacramento Kings'),
#  ('POR', 'Portland Trail Blazers'),
#  ('TOR', 'Washington Wizards'),
#  ('TOR', 'Toronto Raptors'),
#  ('MIA', 'Indiana Pacers'),
#  ('MIA', 'Miami Heat'),
#  ('BRK', 'Golden State Warriors'),
#  ('BRK', 'Brooklyn Nets'),
#  ('MIN', 'Detroit Pistons'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('PHO', 'Chicago Bulls'),
#  ('PHO', 'Phoenix Suns'),
#  ('LAL', 'Denver Nuggets'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('CHO', 'Minnesota Timberwolves'),
#  ('CHO', 'Charlotte Hornets'),
#  ('DET', 'Cleveland Cavaliers'),
#  ('DET', 'Detroit Pistons'),
#  ('ORL', 'Indiana Pacers'),
#  ('ORL', 'Orlando Magic'),
#  ('PHI', 'Utah Jazz'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('NYK', 'Los Angeles Clippers'),
#  ('NYK', 'New York Knicks'),
#  ('MEM', 'Portland Trail Blazers'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIL', 'Washington Wizards'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('NOP', 'Oklahoma City Thunder'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('DAL', 'Boston Celtics'),
#  ('DAL', 'Dallas Mavericks'),
#  ('SAS', 'Atlanta Hawks'),
#  ('SAS', 'San Antonio Spurs'),
#  ('SAC', 'Denver Nuggets'),
#  ('SAC', 'Sacramento Kings'),
#  ('LAL', 'Chicago Bulls'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('CHO', 'Washington Wizards'),
#  ('CHO', 'Charlotte Hornets'),
#  ('CLE', 'Brooklyn Nets'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('PHI', 'Portland Trail Blazers'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('ATL', 'Los Angeles Clippers'),
#  ('ATL', 'Atlanta Hawks'),
#  ('MIA', 'Boston Celtics'),
#  ('MIA', 'Miami Heat'),
#  ('NYK', 'Toronto Raptors'),
#  ('NYK', 'New York Knicks'),
#  ('HOU', 'Denver Nuggets'),
#  ('HOU', 'Houston Rockets'),
#  ('MEM', 'Dallas Mavericks'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIN', 'Orlando Magic'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('NOP', 'San Antonio Spurs'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('OKC', 'Golden State Warriors'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('PHO', 'Milwaukee Bucks'),
#  ('PHO', 'Phoenix Suns'),
#  ('UTA', 'Chicago Bulls'),
#  ('UTA', 'Utah Jazz'),
#  ('SAC', 'Los Angeles Lakers'),
#  ('SAC', 'Sacramento Kings'),
#  ('BRK', 'Portland Trail Blazers'),
#  ('BRK', 'Brooklyn Nets'),
#  ('ATL', 'New York Knicks'),
#  ('ATL', 'Atlanta Hawks'),
#  ('BOS', 'Orlando Magic'),
#  ('BOS', 'Boston Celtics'),
#  ('CLE', 'Charlotte Hornets'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('IND', 'Toronto Raptors'),
#  ('IND', 'Indiana Pacers'),
#  ('MIN', 'Miami Heat'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('OKC', 'Detroit Pistons'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('DEN', 'Memphis Grizzlies'),
#  ('DEN', 'Denver Nuggets'),
#  ('PHO', 'New Orleans Pelicans'),
#  ('PHO', 'Phoenix Suns'),
#  ('GSW', 'Chicago Bulls'),
#  ('GSW', 'Golden State Warriors'),
#  ('CHO', 'San Antonio Spurs'),
#  ('CHO', 'Charlotte Hornets'),
#  ('PHI', 'Orlando Magic'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('WAS', 'Portland Trail Blazers'),
#  ('WAS', 'Washington Wizards'),
#  ('ATL', 'Toronto Raptors'),
#  ('ATL', 'Atlanta Hawks'),
#  ('HOU', 'New York Knicks'),
#  ('HOU', 'Houston Rockets'),
#  ('IND', 'Boston Celtics'),
#  ('IND', 'Indiana Pacers'),
#  ('DAL', 'Oklahoma City Thunder'),
#  ('DAL', 'Dallas Mavericks'),
#  ('GSW', 'New Orleans Pelicans'),
#  ('GSW', 'Golden State Warriors'),
#  ('UTA', 'Milwaukee Bucks'),
#  ('UTA', 'Utah Jazz'),
#  ('SAC', 'Los Angeles Clippers'),
#  ('SAC', 'Sacramento Kings'),
#  ('CHI', 'Miami Heat'),
#  ('CHI', 'Chicago Bulls'),
#  ('MIN', 'Phoenix Suns'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('MEM', 'Brooklyn Nets'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('IND', 'Orlando Magic'),
#  ('IND', 'Indiana Pacers'),
#  ('PHI', 'Cleveland Cavaliers'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('BOS', 'Detroit Pistons'),
#  ('BOS', 'Boston Celtics'),
#  ('NYK', 'Portland Trail Blazers'),
#  ('NYK', 'New York Knicks'),
#  ('HOU', 'Brooklyn Nets'),
#  ('HOU', 'Houston Rockets'),
#  ('SAS', 'Dallas Mavericks'),
#  ('SAS', 'San Antonio Spurs'),
#  ('GSW', 'Sacramento Kings'),
#  ('GSW', 'Golden State Warriors'),
#  ('LAC', 'Los Angeles Lakers'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('CLE', 'Miami Heat'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('CHI', 'Phoenix Suns'),
#  ('CHI', 'Chicago Bulls'),
#  ('MIN', 'Washington Wizards'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('SAC', 'Milwaukee Bucks'),
#  ('SAC', 'Sacramento Kings'),
#  ('UTA', 'Denver Nuggets'),
#  ('UTA', 'Utah Jazz'),
#  ('DET', 'Phoenix Suns'),
#  ('DET', 'Detroit Pistons'),
#  ('ORL', 'Oklahoma City Thunder'),
#  ('ORL', 'Orlando Magic'),
#  ('PHI', 'Washington Wizards'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('NYK', 'Miami Heat'),
#  ('NYK', 'New York Knicks'),
#  ('TOR', 'Charlotte Hornets'),
#  ('TOR', 'Toronto Raptors'),
#  ('HOU', 'Indiana Pacers'),
#  ('HOU', 'Houston Rockets'),
#  ('NOP', 'Minnesota Timberwolves'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('DAL', 'Brooklyn Nets'),
#  ('DAL', 'Dallas Mavericks'),
#  ('SAS', 'Memphis Grizzlies'),
#  ('SAS', 'San Antonio Spurs'),
#  ('LAL', 'Golden State Warriors'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('ATL', 'Cleveland Cavaliers'),
#  ('ATL', 'Atlanta Hawks'),
#  ('BOS', 'Philadelphia 76ers'),
#  ('BOS', 'Boston Celtics'),
#  ('DEN', 'Chicago Bulls'),
#  ('DEN', 'Denver Nuggets'),
#  ('POR', 'Milwaukee Bucks'),
#  ('POR', 'Portland Trail Blazers'),
#  ('LAC', 'Utah Jazz'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('ORL', 'Golden State Warriors'),
#  ('ORL', 'Orlando Magic'),
#  ('WAS', 'Detroit Pistons'),
#  ('WAS', 'Washington Wizards'),
#  ('TOR', 'Indiana Pacers'),
#  ('TOR', 'Toronto Raptors'),
#  ('CHI', 'Sacramento Kings'),
#  ('CHI', 'Chicago Bulls'),
#  ('MEM', 'San Antonio Spurs'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIA', 'Charlotte Hornets'),
#  ('MIA', 'Miami Heat'),
#  ('OKC', 'Minnesota Timberwolves'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('UTA', 'New Orleans Pelicans'),
#  ('UTA', 'Utah Jazz'),
#  ('BOS', 'Phoenix Suns'),
#  ('BOS', 'Boston Celtics'),
#  ('DAL', 'Los Angeles Clippers'),
#  ('DAL', 'Dallas Mavericks'),
#  ('BRK', 'Atlanta Hawks'),
#  ('BRK', 'Brooklyn Nets'),
#  ('CLE', 'Memphis Grizzlies'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('PHI', 'Detroit Pistons'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('MIL', 'Sacramento Kings'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('DEN', 'Los Angeles Lakers'),
#  ('DEN', 'Denver Nuggets'),
#  ('POR', 'New Orleans Pelicans'),
#  ('POR', 'Portland Trail Blazers'),
#  ('NYK', 'Orlando Magic'),
#  ('NYK', 'New York Knicks'),
#  ('MIA', 'Golden State Warriors'),
#  ('MIA', 'Miami Heat'),
#  ('MIN', 'Los Angeles Clippers'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('OKC', 'San Antonio Spurs'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('LAL', 'Houston Rockets'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('CHO', 'Orlando Magic'),
#  ('CHO', 'Charlotte Hornets'),
#  ('IND', 'New York Knicks'),
#  ('IND', 'Indiana Pacers'),
#  ('PHI', 'Phoenix Suns'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('ATL', 'Brooklyn Nets'),
#  ('ATL', 'Atlanta Hawks'),
#  ('BOS', 'Milwaukee Bucks'),
#  ('BOS', 'Boston Celtics'),
#  ('CHI', 'Cleveland Cavaliers'),
#  ('CHI', 'Chicago Bulls'),
#  ('MEM', 'Minnesota Timberwolves'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('NOP', 'Golden State Warriors'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('DAL', 'Denver Nuggets'),
#  ('DAL', 'Dallas Mavericks'),
#  ('SAS', 'Detroit Pistons'),
#  ('SAS', 'San Antonio Spurs'),
#  ('UTA', 'Washington Wizards'),
#  ('UTA', 'Utah Jazz'),
#  ('TOR', 'Phoenix Suns'),
#  ('TOR', 'Toronto Raptors'),
#  ('OKC', 'Utah Jazz'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('POR', 'Washington Wizards'),
#  ('POR', 'Portland Trail Blazers'),
#  ('CLE', 'Sacramento Kings'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('IND', 'Chicago Bulls'),
#  ('IND', 'Indiana Pacers'),
#  ('ORL', 'Atlanta Hawks'),
#  ('ORL', 'Orlando Magic'),
#  ('BOS', 'Dallas Mavericks'),
#  ('BOS', 'Boston Celtics'),
#  ('NYK', 'Memphis Grizzlies'),
#  ('NYK', 'New York Knicks'),
#  ('CHO', 'Golden State Warriors'),
#  ('CHO', 'Charlotte Hornets'),
#  ('MIL', 'Detroit Pistons'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('NOP', 'Denver Nuggets'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('SAS', 'Miami Heat'),
#  ('SAS', 'San Antonio Spurs'),
#  ('LAC', 'Minnesota Timberwolves'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('PHI', 'Los Angeles Lakers'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('PHO', 'Washington Wizards'),
#  ('PHO', 'Phoenix Suns'),
#  ('BRK', 'Oklahoma City Thunder'),
#  ('BRK', 'Brooklyn Nets'),
#  ('UTA', 'Houston Rockets'),
#  ('UTA', 'Utah Jazz'),
#  ('CHO', 'Chicago Bulls'),
#  ('CHO', 'Charlotte Hornets'),
#  ('DET', 'Golden State Warriors'),
#  ('DET', 'Detroit Pistons'),
#  ('IND', 'Cleveland Cavaliers'),
#  ('IND', 'Indiana Pacers'),
#  ('ORL', 'Denver Nuggets'),
#  ('ORL', 'Orlando Magic'),
#  ('MEM', 'Toronto Raptors'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIL', 'Dallas Mavericks'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('NOP', 'Sacramento Kings'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('SAS', 'Boston Celtics'),
#  ('SAS', 'San Antonio Spurs'),
#  ('LAC', 'Washington Wizards'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('BRK', 'Miami Heat'),
#  ('BRK', 'Brooklyn Nets'),
#  ('CHO', 'Los Angeles Lakers'),
#  ('CHO', 'Charlotte Hornets'),
#  ('ATL', 'Orlando Magic'),
#  ('ATL', 'Atlanta Hawks'),
#  ('CHI', 'New York Knicks'),
#  ('CHI', 'Chicago Bulls'),
#  ('CLE', 'Philadelphia 76ers'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('MIL', 'Utah Jazz'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('MEM', 'Oklahoma City Thunder'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('PHO', 'San Antonio Spurs'),
#  ('PHO', 'Phoenix Suns'),
#  ('POR', 'Houston Rockets'),
#  ('POR', 'Portland Trail Blazers'),
#  ('SAC', 'Toronto Raptors'),
#  ('SAC', 'Sacramento Kings'),
#  ('DET', 'Boston Celtics'),
#  ('DET', 'Detroit Pistons'),
#  ('IND', 'Denver Nuggets'),
#  ('IND', 'Indiana Pacers'),
#  ('MIN', 'Dallas Mavericks'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('NOP', 'Philadelphia 76ers'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('NYK', 'Atlanta Hawks'),
#  ('NYK', 'New York Knicks'),
#  ('CHI', 'Boston Celtics'),
#  ('CHI', 'Chicago Bulls'),
#  ('HOU', 'New Orleans Pelicans'),
#  ('HOU', 'Houston Rockets'),
#  ('MEM', 'Miami Heat'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('OKC', 'Charlotte Hornets'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('GSW', 'Portland Trail Blazers'),
#  ('GSW', 'Golden State Warriors'),
#  ('LAC', 'Toronto Raptors'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('CLE', 'Atlanta Hawks'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('DET', 'Denver Nuggets'),
#  ('DET', 'Detroit Pistons'),
#  ('NYK', 'Los Angeles Lakers'),
#  ('NYK', 'New York Knicks'),
#  ('BRK', 'Washington Wizards'),
#  ('BRK', 'Brooklyn Nets'),
#  ('DAL', 'San Antonio Spurs'),
#  ('DAL', 'Dallas Mavericks'),
#  ('MIN', 'Philadelphia 76ers'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('SAC', 'Phoenix Suns'),
#  ('SAC', 'Sacramento Kings'),
#  ('IND', 'Oklahoma City Thunder'),
#  ('IND', 'Indiana Pacers'),
#  ('ORL', 'Los Angeles Clippers'),
#  ('ORL', 'Orlando Magic'),
#  ('WAS', 'Memphis Grizzlies'),
#  ('WAS', 'Washington Wizards'),
#  ('BOS', 'Denver Nuggets'),
#  ('BOS', 'Boston Celtics'),
#  ('MIA', 'Portland Trail Blazers'),
#  ('MIA', 'Miami Heat'),
#  ('CHI', 'Utah Jazz'),
#  ('CHI', 'Chicago Bulls'),
#  ('NOP', 'Milwaukee Bucks'),
#  ('NOP', 'New Orleans Pelicans'),
#  ('PHO', 'Toronto Raptors'),
#  ('PHO', 'Phoenix Suns'),
#  ('HOU', 'Charlotte Hornets'),
#  ('HOU', 'Houston Rockets'),
#  ('ATL', 'Detroit Pistons'),
#  ('ATL', 'Atlanta Hawks'),
#  ('BRK', 'New York Knicks'),
#  ('BRK', 'Brooklyn Nets'),
#  ('CLE', 'Los Angeles Lakers'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('MIN', 'Sacramento Kings'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('GSW', 'Dallas Mavericks'),
#  ('GSW', 'Golden State Warriors'),
#  ('CHO', 'Miami Heat'),
#  ('CHO', 'Charlotte Hornets'),
#  ('IND', 'Detroit Pistons'),
#  ('IND', 'Indiana Pacers'),
#  ('ORL', 'Portland Trail Blazers'),
#  ('ORL', 'Orlando Magic'),
#  ('PHI', 'Oklahoma City Thunder'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('WAS', 'Los Angeles Clippers'),
#  ('WAS', 'Washington Wizards'),
#  ('BOS', 'Utah Jazz'),
#  ('BOS', 'Boston Celtics'),
#  ('TOR', 'Brooklyn Nets'),
#  ('TOR', 'Toronto Raptors'),
#  ('MEM', 'Atlanta Hawks'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIL', 'Chicago Bulls'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('DEN', 'New Orleans Pelicans'),
#  ('DEN', 'Denver Nuggets'),
#  ('HOU', 'San Antonio Spurs'),
#  ('HOU', 'Houston Rockets'),
#  ('CHO', 'Portland Trail Blazers'),
#  ('CHO', 'Charlotte Hornets'),
#  ('CLE', 'Utah Jazz'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('NYK', 'Oklahoma City Thunder'),
#  ('NYK', 'New York Knicks'),
#  ('HOU', 'Milwaukee Bucks'),
#  ('HOU', 'Houston Rockets'),
#  ('MIA', 'Los Angeles Clippers'),
#  ('MIA', 'Miami Heat'),
#  ('MIN', 'Phoenix Suns'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('SAS', 'Dallas Mavericks'),
#  ('SAS', 'San Antonio Spurs'),
#  ('MEM', 'Boston Celtics'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('TOR', 'Sacramento Kings'),
#  ('TOR', 'Toronto Raptors'),
#  ('DET', 'Orlando Magic'),
#  ('DET', 'Detroit Pistons'),
#  ('BRK', 'Indiana Pacers'),
#  ('BRK', 'Brooklyn Nets'),
#  ('WAS', 'Cleveland Cavaliers'),
#  ('WAS', 'Washington Wizards'),
#  ('CHO', 'New York Knicks'),
#  ('CHO', 'Charlotte Hornets'),
#  ('IND', 'Boston Celtics'),
#  ('IND', 'Indiana Pacers'),
#  ('ATL', 'Miami Heat'),
#  ('ATL', 'Atlanta Hawks'),
#  ('CHI', 'Philadelphia 76ers'),
#  ('CHI', 'Chicago Bulls'),
#  ('HOU', 'Utah Jazz'),
#  ('HOU', 'Houston Rockets'),
#  ('MIN', 'Portland Trail Blazers'),
#  ('MIN', 'Minnesota Timberwolves'),
#  ('OKC', 'Denver Nuggets'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('DAL', 'Phoenix Suns'),
#  ('DAL', 'Dallas Mavericks'),
#  ('SAS', 'Los Angeles Clippers'),
#  ('SAS', 'San Antonio Spurs'),
#  ('LAL', 'Golden State Warriors'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('PHI', 'Sacramento Kings'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('WAS', 'New Orleans Pelicans'),
#  ('WAS', 'Washington Wizards'),
#  ('MIL', 'Cleveland Cavaliers'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('CHO', 'Toronto Raptors'),
#  ('CHO', 'Charlotte Hornets'),
#  ('ATL', 'Indiana Pacers'),
#  ('ATL', 'Atlanta Hawks'),
#  ('BOS', 'Miami Heat'),
#  ('BOS', 'Boston Celtics'),
#  ('BRK', 'Sacramento Kings'),
#  ('BRK', 'Brooklyn Nets'),
#  ('CHI', 'Orlando Magic'),
#  ('CHI', 'Chicago Bulls'),
#  ('HOU', 'Los Angeles Lakers'),
#  ('HOU', 'Houston Rockets'),
#  ('OKC', 'Utah Jazz'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('DAL', 'Detroit Pistons'),
#  ('DAL', 'Dallas Mavericks'),
#  ('DEN', 'Minnesota Timberwolves'),
#  ('DEN', 'Denver Nuggets'),
#  ('POR', 'San Antonio Spurs'),
#  ('POR', 'Portland Trail Blazers'),
#  ('GSW', 'Memphis Grizzlies'),
#  ('GSW', 'Golden State Warriors'),
#  ('LAC', 'Phoenix Suns'),
#  ('LAC', 'Los Angeles Clippers'),
#  ('CLE', 'Chicago Bulls'),
#  ('CLE', 'Cleveland Cavaliers'),
#  ('PHI', 'Toronto Raptors'),
#  ('PHI', 'Philadelphia 76ers'),
#  ('NYK', 'Boston Celtics'),
#  ('NYK', 'New York Knicks'),
#  ('PHO', 'Memphis Grizzlies'),
#  ('PHO', 'Phoenix Suns'),
#  ('UTA', 'San Antonio Spurs'),
#  ('UTA', 'Utah Jazz'),
#  ('DET', 'New York Knicks'),
#  ('DET', 'Detroit Pistons'),
#  ('ORL', 'New Orleans Pelicans'),
#  ('ORL', 'Orlando Magic'),
#  ('BRK', 'Washington Wizards'),
#  ('BRK', 'Brooklyn Nets'),
#  ('HOU', 'Los Angeles Clippers'),
#  ('HOU', 'Houston Rockets'),
#  ('MIA', 'Dallas Mavericks'),
#  ('MIA', 'Miami Heat'),
#  ('MIL', 'Charlotte Hornets'),
#  ('MIL', 'Milwaukee Bucks'),
#  ('OKC', 'Atlanta Hawks'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('POR', 'Denver Nuggets'),
#  ('POR', 'Portland Trail Blazers'),
#  ('GSW', 'Los Angeles Lakers'),
#  ('GSW', 'Golden State Warriors'),
#  ('TOR', 'Philadelphia 76ers'),
#  ('TOR', 'Toronto Raptors'),
#  ('CHO', 'Milwaukee Bucks'),
#  ('CHO', 'Charlotte Hornets'),
#  ('IND', 'Brooklyn Nets'),
#  ('IND', 'Indiana Pacers'),
#  ('WAS', 'Orlando Magic'),
#  ('WAS', 'Washington Wizards'),
#  ('ATL', 'Dallas Mavericks'),
#  ('ATL', 'Atlanta Hawks'),
#  ('BOS', 'Chicago Bulls'),
#  ('BOS', 'Boston Celtics'),
#  ('MEM', 'Los Angeles Clippers'),
#  ('MEM', 'Memphis Grizzlies'),
#  ('MIA', 'New Orleans Pelicans'),
#  ('MIA', 'Miami Heat'),
#  ('UTA', 'Oklahoma City Thunder'),
#  ('UTA', 'Utah Jazz'),
#  ('GSW', 'Denver Nuggets'),
#  ('GSW', 'Golden State Warriors'),
#  ('PHO', 'Minnesota Timberwolves'),
#  ('PHO', 'Phoenix Suns'),
#  ('LAL', 'Portland Trail Blazers'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('SAC', 'San Antonio Spurs'),
#  ('SAC', 'Sacramento Kings'),
#  ('NYK', 'Philadelphia 76ers'),
#  ('NYK', 'New York Knicks'),
#  ('GSW', 'Cleveland Cavaliers'),
#  ('GSW', 'Golden State Warriors'),
#  ('BOS', 'Washington Wizards'),
#  ('BOS', 'Boston Celtics'),
#  ('OKC', 'Houston Rockets'),
#  ('OKC', 'Oklahoma City Thunder'),
#  ('LAL', 'Minnesota Timberwolves'),
#  ('LAL', 'Los Angeles Lakers'),
#  ('DAL', 'Toronto Raptors'),
#  ('DAL', 'Dallas Mavericks'),
#  ('DET', 'Indiana Pacers'),
#  ('DET', 'Detroit Pistons'),
#  ('MIA', 'Orlando Magic'),
#  ('MIA', 'Miami Heat'),
#  ...]

# %%
len(df_h)
# Out:
# 3282

# %%
for x in range(len(df_h)):
    if d[x] in dict_conv.items():
        df_h['homeaway'][x] = 1
    else:
        df_h['homeaway'][x] = 0
# Out:
# /Users/fayadabbasi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/fayadabbasi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_h.head(20)
# Out:
#                    Player  loc  homeaway
# 0          Boston Celtics  CLE         0
# 1     Cleveland Cavaliers  CLE         1
# 2         Houston Rockets  GSW         0
# 3   Golden State Warriors  GSW         1
# 4       Charlotte Hornets  DET         0
# 5         Detroit Pistons  DET         1
# 6           Brooklyn Nets  IND         0
# 7          Indiana Pacers  IND         1
# 8              Miami Heat  ORL         0
# 9           Orlando Magic  ORL         1
# 10     Philadelphia 76ers  WAS         0
# 11     Washington Wizards  WAS         1
# 12        Milwaukee Bucks  BOS         0
# 13         Boston Celtics  BOS         1
# 14   New Orleans Pelicans  MEM         0
# 15      Memphis Grizzlies  MEM         1
# 16          Atlanta Hawks  DAL         0
# 17       Dallas Mavericks  DAL         1
# 18         Denver Nuggets  UTA         0
# 19              Utah Jazz  UTA         1

# %%
df_team_efg = pd.read_sql_query('select "Player", AVG("eFG") AS efg, AVG("TOV_per") AS tov, AVG("ORB_per") AS orb, AVG("FTr") AS ftr FROM nbafourfactorfour GROUP BY "Player" ORDER BY efg DESC', con=engine)

# %%
df_team_efg.rename_axis("efg").head(5)
# Out:
#                     Player       efg       tov       orb       ftr
# efg
# 0    Golden State Warriors  0.563671  0.132072  0.195865  0.198043
# 1          Toronto Raptors  0.544971  0.119382  0.221198  0.202353
# 2          Houston Rockets  0.543482  0.119446  0.216896  0.227290
# 3          Milwaukee Bucks  0.540492  0.124391  0.202997  0.213714
# 4     New Orleans Pelicans  0.538899  0.128788  0.204307  0.192881

# %%
df_team_tov = pd.read_sql_query('select "Player", AVG("eFG") AS efg, AVG("TOV_per") AS tov, AVG("ORB_per") AS orb, AVG("FTr") AS ftr FROM nbafourfactorfour GROUP BY "Player" ORDER BY tov ASC', con=engine)

# %%
df_team_tov.rename_axis("tov").head(5)
# Out:
#                      Player       efg       tov       orb       ftr
# tov
# 0         Charlotte Hornets  0.513300  0.109896  0.218904  0.228463
# 1    Minnesota Timberwolves  0.519808  0.110109  0.242956  0.222976
# 2         San Antonio Spurs  0.504876  0.115525  0.234163  0.195649
# 3          Dallas Mavericks  0.518710  0.116915  0.199746  0.179654
# 4           Detroit Pistons  0.510063  0.117453  0.236885  0.180501

# %%
df_team_orb = pd.read_sql_query('select "Player", AVG("eFG") AS efg, AVG("TOV_per") AS tov, AVG("ORB_per") AS orb, AVG("FTr") AS ftr FROM nbafourfactorfour GROUP BY "Player" ORDER BY orb DESC', con=engine)

# %%
df_team_orb.rename_axis("orb").head(5)
# Out:
#                      Player       efg       tov       orb       ftr
# orb
# 0     Oklahoma City Thunder  0.511340  0.119798  0.269211  0.197406
# 1            Denver Nuggets  0.533726  0.127177  0.247767  0.195977
# 2           New York Knicks  0.506601  0.126998  0.243593  0.182897
# 3    Minnesota Timberwolves  0.519808  0.110109  0.242956  0.222976
# 4           Detroit Pistons  0.510063  0.117453  0.236885  0.180501

# %%
df_team_ftr = pd.read_sql_query('select "Player", AVG("eFG") AS efg, AVG("TOV_per") AS tov, AVG("ORB_per") AS orb, AVG("FTr") AS ftr FROM nbafourfactorfour GROUP BY "Player" ORDER BY ftr DESC', con=engine)

# %%
df_team_ftr.rename_axis("ftr").head(5)
# Out:
#                      Player       efg       tov       orb       ftr
# ftr
# 0      Los Angeles Clippers  0.528590  0.125293  0.224315  0.234951
# 1         Charlotte Hornets  0.513300  0.109896  0.218904  0.228463
# 2           Houston Rockets  0.543482  0.119446  0.216896  0.227290
# 3    Minnesota Timberwolves  0.519808  0.110109  0.242956  0.222976
# 4        Philadelphia 76ers  0.530170  0.137565  0.228185  0.218763

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax10 = sns.boxplot(x=tips["total_bill"])
tips.head()
x = tips.groupby('day').count()
x
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Thur          62   62   62      62    62    62
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76

# %%
ax20 = sns.boxplot(x=df_home['eFG'])

# %%
boxplot_x = [df_home['eFG'], df_home['FTr'], df_home['ORB_per'], df_home['TOV_per']]

# %%
sns.boxplot(x=boxplot_x)
