# %%
import sqlalchemy as sqa
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
engine = create_engine('postgresql+psycopg2://postgres:docker@localhost:5432/nbafourfactor')

# %%
df = pd.read_sql_query('select * FROM nbafourfactorfour', con=engine)

# %%
df.head()
# Out:
#                   Player   MP  FG  FGA  3P  FT  ORB  TOV  FTA  DRB  PTS  \
# 0         Boston Celtics  240  36   88   8  19    9   10   25   37   99
# 1    Cleveland Cavaliers  240  38   83   5  21    9   17   25   41  102
# 2        Houston Rockets  240  47   97  15  13   10   12   19   33  122
# 3  Golden State Warriors  240  43   80  16  19    6   17   21   35  121
# 4      Charlotte Hornets  240  29   73   9  23    3   17   29   44   90
#
#                         Date       eFG   TOV_per   ORB_per       FTr  \
# 0   8:01 PM  October 17 2017  0.454545  0.091743  0.195652  0.215909
# 1   8:01 PM  October 17 2017  0.487952  0.153153  0.180000  0.253012
# 2  10:30 PM  October 17 2017  0.561856  0.102249  0.232558  0.134021
# 3  10:30 PM  October 17 2017  0.637500  0.160015  0.146341  0.237500
# 4   7:00 PM  October 18 2017  0.458904  0.165434  0.063830  0.315068
#
#           id_t  loc
# 0  20171017CLE  CLE
# 1  20171017CLE  CLE
# 2  20171017GSW  GSW
# 3  20171017GSW  GSW
# 4  20171018DET  DET

# %%
np.mean(df['TOV_per'])
# Out:
# 0.12488605469511148

# %%
np.mean(df['eFG'])
# Out:
# 0.5220177575462226

# %%
np.mean(df['ORB_per'])
# Out:
# 0.22264922360482722

# %%
np.mean(df['FTr'])
# Out:
# 0.1980419334247778

# %%
analysis_list = ['eFG', 'TOV_per', 'ORB_per', 'FTr']
for items in analysis_list:
    df.hist(column=items, bins=20)

# %%
df_h = pd.read_sql_query('select "Player", loc FROM nbafourfactorfour', con=engine)

# %%
df_h
# Out:
#                       Player  loc
# 0             Boston Celtics  CLE
# 1        Cleveland Cavaliers  CLE
# 2            Houston Rockets  GSW
# 3      Golden State Warriors  GSW
# 4          Charlotte Hornets  DET
# 5            Detroit Pistons  DET
# 6              Brooklyn Nets  IND
# 7             Indiana Pacers  IND
# 8                 Miami Heat  ORL
# 9              Orlando Magic  ORL
# 10        Philadelphia 76ers  WAS
# 11        Washington Wizards  WAS
# 12           Milwaukee Bucks  BOS
# 13            Boston Celtics  BOS
# 14      New Orleans Pelicans  MEM
# 15         Memphis Grizzlies  MEM
# 16             Atlanta Hawks  DAL
# 17          Dallas Mavericks  DAL
# 18            Denver Nuggets  UTA
# 19                 Utah Jazz  UTA
# 20    Minnesota Timberwolves  SAS
# 21         San Antonio Spurs  SAS
# 22    Portland Trail Blazers  PHO
# 23              Phoenix Suns  PHO
# 24           Houston Rockets  SAC
# 25          Sacramento Kings  SAC
# 26             Chicago Bulls  TOR
# 27           Toronto Raptors  TOR
# 28           New York Knicks  OKC
# 29     Oklahoma City Thunder  OKC
# ...                      ...  ...
# 3252            Phoenix Suns  LAC
# 3253    Los Angeles Clippers  LAC
# 3254   Golden State Warriors  TOR
# 3255         Toronto Raptors  TOR
# 3256          Indiana Pacers  LAL
# 3257      Los Angeles Lakers  LAL
# 3258    Los Angeles Clippers  SAC
# 3259        Sacramento Kings  SAC
# 3260     Cleveland Cavaliers  BOS
# 3261          Boston Celtics  BOS
# 3262               Utah Jazz  CHO
# 3263       Charlotte Hornets  CHO
# 3264           Chicago Bulls  DET
# 3265         Detroit Pistons  DET
# 3266      Washington Wizards  PHI
# 3267      Philadelphia 76ers  PHI
# 3268       Memphis Grizzlies  BRK
# 3269           Brooklyn Nets  BRK
# 3270    New Orleans Pelicans  MIA
# 3271              Miami Heat  MIA
# 3272           Atlanta Hawks  OKC
# 3273   Oklahoma City Thunder  OKC
# 3274         Houston Rockets  SAS
# 3275       San Antonio Spurs  SAS
# 3276           Orlando Magic  PHO
# 3277            Phoenix Suns  PHO
# 3278        Dallas Mavericks  LAL
# 3279      Los Angeles Lakers  LAL
# 3280          Denver Nuggets  POR
# 3281  Portland Trail Blazers  POR
#
# [3282 rows x 2 columns]

# %%
dict_conv = {
    'ATL': 'Atlanta Hawks',
    'BOS': 'Boston Celtics',
    'BRK': 'Brooklyn Nets',
    'CHI': 'Chicago Bulls',
    'CHO': 'Charlotte Hornets',
    'CLE': 'Cleveland Cavaliers',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'NOP': 'New Orleans Pelicans',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHO': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'SAC': 'Sacramento Kings',
    'SAS': 'San Antonio Spurs',
    'TOR': 'Toronto Raptors',
    'UTA': 'Utah Jazz',
    'WAS': 'Washington Wizards'}
